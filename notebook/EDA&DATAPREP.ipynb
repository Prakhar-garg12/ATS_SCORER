# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('resumeJD_pairs.csv', engine='python', on_bad_lines='skip')
print(f"Data Loaed: {df.shape[0]:,} rows, {df.shape[1]} columns")
# Out:
# Data Loaed: 320 rows, 4 columns

# %%
df.describe()
# Out:
#        match_score
# count   320.000000
# mean      0.652906
# std       0.284471
# min       0.100000
# 25%       0.460000
# 50%       0.775000
# 75%       0.900000
# max       0.950000

# %%
print(f"\nColumns: {list(df.columns)}")
# Out:
# Columns: ['resume_text', 'job_description', 'match_score', 'match_label']

# %%
df.head()
# Out:
#                                          resume_text  \
# 0  Project manager with 5 years of experience in ...
# 1  Senior data analyst with 10 years of experienc...
# 2  Logistics coordinator with 2 years of experien...
# 3  Interior designer with 8 years of experience i...
# 4  Chef with 6 years of experience in French cuis...
#
#                                      job_description  match_score match_label
# 0  Engineering Manager at tech firm. Required: en...         0.67      medium
# 1  Senior Business Intelligence Analyst at enterp...         0.92        high
# 2  Mobile App Developer at startup. Required: Rea...         0.25         low
# 3  Backend Engineer at fintech. Required: Java/Sc...         0.27         low
# 4  Cybersecurity Analyst at financial firm. Requi...         0.19         low

# %%
print("Dataset Info:")
print("=" * 60)
df.info()
# Out:
# Dataset Info:
# ============================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resume_text      320 non-null    object
#  1   job_description  320 non-null    object
#  2   match_score      320 non-null    float64
#  3   match_label      320 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 10.1+ KB

# %%
# text columns summary
print("\nText Columns Summary:")
df.describe(include='object')
# Out:
# Text Columns Summary:
#                                               resume_text  \
# count                                                 320
# unique                                                295
# top     Product manager with 8 years of experience in ...
# freq                                                    3
#
#                                           job_description match_label
# count                                                 320         320
# unique                                                 31           3
# top     Senior Business Intelligence Analyst at enterp...        high
# freq                                                   11         160

# %%
# Check for the missing values
print("Missing Values Analysis:")
print("=" * 60)
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100
missing_df = pd.DataFrame({
    'Missing_Count': missing,
    'Percentage': missing_pct
})
print(missing_df)
print(f"\nTotal missing values: {missing.sum()}")
# Out:
# Missing Values Analysis:
# ============================================================
#                  Missing_Count  Percentage
# resume_text                  0         0.0
# job_description              0         0.0
# match_score                  0         0.0
# match_label                  0         0.0
#
# Total missing values: 0

# %%
full_dupes = df.duplicated().sum()
print(f"Full duplicate rows: {full_dupes}")
# Out:
# Full duplicate rows: 4

# %%
pair_dupes = df.duplicated(subset=['resume_text', 'job_description']).sum()
print(f"Duplicate resume+JD pairs: {pair_dupes}")
# Out:
# Duplicate resume+JD pairs: 25

# %%
print("\nDuplicate rows:")
df[df.duplicated(subset=['resume_text', 'job_description'], keep=False)]
# Out:
# Duplicate rows:
#                                            resume_text  \
# 1    Senior data analyst with 10 years of experienc...
# 10   Web designer with 10 years of experience in Wo...
# 11   Customer support lead with 3 years of experien...
# 20   Cybersecurity analyst with 6 years of experien...
# 29   Marketing coordinator with 5 years of experien...
# 37   Graphic designer with 2 years of experience in...
# 55   Data entry specialist with 6 years of experien...
# 61   Machine learning engineer with 9 years of expe...
# 66   Marketing coordinator with 5 years of experien...
# 71   Journalist with 8 years of experience in inves...
# 72   Real estate agent with 2 years of experience i...
# 78   Interior designer with 7 years of experience i...
# 80   Software developer with 9 years of experience ...
# 86   Interior designer with 3 years of experience i...
# 89   Data entry specialist with 6 years of experien...
# 92   Project manager with 6 years of experience in ...
# 108  Cloud architect with 8 years of experience des...
# 111  Product manager with 8 years of experience in ...
# 117  Cybersecurity analyst with 6 years of experien...
# 118  Marketing coordinator with 5 years of experien...
# 120  Graphic designer with 2 years of experience in...
# 121  Business analyst with 3 years of experience in...
# 146  Full stack developer with 3 years of experienc...
# 150  Machine learning engineer with 9 years of expe...
# 161  Interior designer with 7 years of experience i...
# 167  Product manager with 8 years of experience in ...
# 175  Mobile app developer with 6 years of experienc...
# 179  Cybersecurity analyst with 6 years of experien...
# 183  Project manager with 6 years of experience in ...
# 190  Financial analyst with 7 years of experience i...
# 192  Network engineer with 9 years of experience in...
# 199  Software developer with 9 years of experience ...
# 206  Cybersecurity analyst with 6 years of experien...
# 209  Senior data analyst with 10 years of experienc...
# 223  Mobile app developer with 6 years of experienc...
# 226  Web designer with 10 years of experience in Wo...
# 234  Cloud architect with 8 years of experience des...
# 252  Real estate agent with 2 years of experience i...
# 261  Journalist with 8 years of experience in inves...
# 279  Network engineer with 9 years of experience in...
# 285  Machine learning engineer with 3 years of expe...
# 292  Interior designer with 3 years of experience i...
# 293  Full stack developer with 3 years of experienc...
# 299  Business analyst with 3 years of experience in...
# 301  Financial analyst with 7 years of experience i...
# 303  Product manager with 8 years of experience in ...
# 309  Customer support lead with 3 years of experien...
# 318  Machine learning engineer with 3 years of expe...
#
#                                        job_description  match_score  \
# 1    Senior Business Intelligence Analyst at enterp...         0.92
# 10   Full Stack Developer at startup. Required: Rea...         0.63
# 11   Sales Manager at SaaS company. Required: B2B s...         0.63
# 20   Cybersecurity Analyst at enterprise firm. Requ...         0.86
# 29   Digital Marketing Manager at e-commerce compan...         0.68
# 37   Frontend Developer at product company. Require...         0.53
# 55   Data Analyst at analytics company. Required: S...         0.60
# 61   ML Engineer at AI company. Required: TensorFlo...         0.90
# 66   Digital Marketing Manager at e-commerce compan...         0.62
# 71   Machine Learning Engineer at AI startup. Requi...         0.29
# 72   Cloud Infrastructure Engineer at tech company....         0.15
# 78   Backend Engineer at fintech. Required: Java/Sc...         0.10
# 80   Full Stack Engineer at fintech company. Requir...         0.71
# 86   Backend Engineer at fintech. Required: Java/Sc...         0.15
# 89   Data Analyst at analytics company. Required: S...         0.63
# 92   Engineering Manager at tech firm. Required: en...         0.57
# 108  Cloud Architect at enterprise company. Require...         0.88
# 111  Product Manager at tech company. Required: agi...         0.87
# 117  Cybersecurity Analyst at enterprise firm. Requ...         0.89
# 118  Digital Marketing Manager at e-commerce compan...         0.60
# 120  Frontend Developer at product company. Require...         0.60
# 121  Senior Data Scientist at tech company. Require...         0.56
# 146  Full Stack Engineer at startup. Required skill...         0.91
# 150  ML Engineer at AI company. Required: TensorFlo...         0.90
# 161  Backend Engineer at fintech. Required: Java/Sc...         0.14
# 167  Product Manager at tech company. Required: agi...         0.87
# 175  Mobile Developer at app startup. Required: Swi...         0.93
# 179  Cybersecurity Analyst at enterprise firm. Requ...         0.91
# 183  Engineering Manager at tech firm. Required: en...         0.58
# 190  Financial Analyst at investment firm. Required...         0.86
# 192  Network Engineer at telecom company. Required:...         0.90
# 199  Full Stack Engineer at fintech company. Requir...         0.69
# 206  Cybersecurity Analyst at enterprise firm. Requ...         0.88
# 209  Senior Business Intelligence Analyst at enterp...         0.92
# 223  Mobile Developer at app startup. Required: Swi...         0.90
# 226  Full Stack Developer at startup. Required: Rea...         0.58
# 234  Cloud Architect at enterprise company. Require...         0.94
# 252  Cloud Infrastructure Engineer at tech company....         0.17
# 261  Machine Learning Engineer at AI startup. Requi...         0.16
# 279  Network Engineer at telecom company. Required:...         0.89
# 285  ML Engineer at AI company. Required: TensorFlo...         0.90
# 292  Backend Engineer at fintech. Required: Java/Sc...         0.20
# 293  Full Stack Engineer at startup. Required skill...         0.94
# 299  Senior Data Scientist at tech company. Require...         0.63
# 301  Financial Analyst at investment firm. Required...         0.92
# 303  Product Manager at tech company. Required: agi...         0.89
# 309  Sales Manager at SaaS company. Required: B2B s...         0.63
# 318  ML Engineer at AI company. Required: TensorFlo...         0.95
#
#     match_label
# 1          high
# 10       medium
# 11       medium
# 20         high
# 29       medium
# 37       medium
# 55       medium
# 61         high
# 66       medium
# 71          low
# 72          low
# 78          low
# 80       medium
# 86          low
# 89       medium
# 92       medium
# 108        high
# 111        high
# 117        high
# 118      medium
# 120      medium
# 121      medium
# 146        high
# 150        high
# 161         low
# 167        high
# 175        high
# 179        high
# 183      medium
# 190        high
# 192        high
# 199      medium
# 206        high
# 209        high
# 223        high
# 226      medium
# 234        high
# 252         low
# 261         low
# 279        high
# 285        high
# 292         low
# 293        high
# 299      medium
# 301        high
# 303        high
# 309      medium
# 318        high

# %%
# ─── Section: Uniqueness Checks ───────────────────────────────────────────────

print(f"Total rows:          {len(df)}")
print(f"Unique resumes:      {df['resume_text'].nunique()}")
print(f"Unique JDs:          {df['job_description'].nunique()}")
print(f"Unique resume+JD pairs: {df[['resume_text','job_description']].drop_duplicates().shape[0]}")
# Out:
# Total rows:          320
# Unique resumes:      295
# Unique JDs:          31
# Unique resume+JD pairs: 295

# %%
# ─── Section: Label Consistency ───────────────────────────────────────────────

# What labels exist? (spot the case inconsistency!)
print("Unique labels found:")
print(df['match_label'].value_counts())

# Is the casing consistent?
print(f"\nExpected 3 labels, got: {df['match_label'].nunique()} unique values")
print("Distinct values:", df['match_label'].unique())
# Out:
# Unique labels found:
# match_label
# high      160
# medium     80
# low        80
# Name: count, dtype: int64
#
# Expected 3 labels, got: 3 unique values
# Distinct values: ['medium' 'high' 'low']

# %%
print("Score distribution:")
print(df['match_score'].describe())
print()

# Scores must be between 0.0 and 1.0 — flag the bad ones
invalid_scores = df[(df['match_score'] < 0) | (df['match_score'] > 1)]
print(f"Invalid scores (out of 0–1 range): {len(invalid_scores)}")
print(invalid_scores[['match_label', 'match_score']])
# Out:
# Score distribution:
# count    320.000000
# mean       0.652906
# std        0.284471
# min        0.100000
# 25%        0.460000
# 50%        0.775000
# 75%        0.900000
# max        0.950000
# Name: match_score, dtype: float64
#
# Invalid scores (out of 0–1 range): 0
# Empty DataFrame
# Columns: [match_label, match_score]
# Index: []

# %%
# ─── Section: Null Values ─────────────────────────────────────────────────────

print("Missing values per column:")
print(df.isnull().sum())
print()

# Show the rows with nulls
nulls = df[df.isnull().any(axis=1)]
print(f"Rows with at least one null: {len(nulls)}")
nulls[['match_label', 'match_score']].head(10)
# Out:
# Missing values per column:
# resume_text        0
# job_description    0
# match_score        0
# match_label        0
# dtype: int64
#
# Rows with at least one null: 0
# Empty DataFrame
# Columns: [match_label, match_score]
# Index: []

# %%
print("=" * 50)
print("DATA QUALITY REPORT — merged_dataset.csv")
print("=" * 50)
print(f"  Total rows:             {len(df)}")
print(f"  Full duplicates:        {df.duplicated().sum()}")
print(f"  Duplicate pairs:        {df.duplicated(subset=['resume_text','job_description']).sum()}")
print(f"  Null resume_text:       {df['resume_text'].isnull().sum()}")
print(f"  Null job_description:   {df['job_description'].isnull().sum()}")
print(f"  Label case variants:    {df['match_label'].nunique()} (expected 3)")
print(f"  Invalid scores (<0/>1): {((df['match_score'] < 0) | (df['match_score'] > 1)).sum()}")
print("=" * 50)
# Out:
# ==================================================
# DATA QUALITY REPORT — merged_dataset.csv
# ==================================================
#   Total rows:             320
#   Full duplicates:        4
#   Duplicate pairs:        25
#   Null resume_text:       0
#   Null job_description:   0
#   Label case variants:    3 (expected 3)
#   Invalid scores (<0/>1): 0
# ==================================================

# %%
# Pie chart + bar side by side
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

counts = df['match_label'].str.lower().value_counts()

axes[0].bar(counts.index, counts.values, color=['green','orange','red'])
axes[0].set_title('Label Distribution (Bar)')
axes[0].set_ylabel('Count')

axes[1].pie(counts.values, labels=counts.index, autopct='%1.1f%%',
            colors=['green','orange','red'])
axes[1].set_title('Label Distribution (Pie)')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Before cleaning
axes[0].hist(df['match_score'], bins=40, color='salmon', edgecolor='black')
axes[0].set_title('Score Distribution (Raw — with dirty data)')
axes[0].set_xlabel('match_score')
axes[0].axvline(1.0, color='red', linestyle='--', label='Max valid = 1.0')
axes[0].legend()

# After cleaning
clean = df[(df['match_score'] >= 0) & (df['match_score'] <= 1)]
axes[1].hist(clean['match_score'], bins=40, color='steelblue', edgecolor='black')
axes[1].set_title('Score Distribution (Cleaned)')
axes[1].set_xlabel('match_score')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

df_plot = df.copy()
df_plot['match_label'] = df_plot['match_label'].str.lower()
df_plot = df_plot[(df_plot['match_score'] >= 0) & (df_plot['match_score'] <= 1)]

plt.figure(figsize=(10, 6))
sns.violinplot(data=df_plot, x='match_label', y='match_score',
               order=['low','medium','high'],
               palette=['red','orange','green'])
plt.title('Score Distribution per Label')
plt.xlabel('Match Label')
plt.ylabel('Match Score')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16784\2750563499.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_plot, x='match_label', y='match_score',

# %%
df_plot['resume_len'] = df_plot['resume_text'].str.split().str.len()
df_plot['jd_len']     = df_plot['job_description'].str.split().str.len()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(df_plot['resume_len'], bins=30, color='steelblue', edgecolor='black')
axes[0].set_title('Resume Word Count Distribution')
axes[0].set_xlabel('Words')

axes[1].hist(df_plot['jd_len'], bins=30, color='coral', edgecolor='black')
axes[1].set_title('Job Description Word Count Distribution')
axes[1].set_xlabel('Words')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].scatter(df_plot['resume_len'], df_plot['match_score'], alpha=0.5, color='steelblue')
axes[0].set_xlabel('Resume Word Count')
axes[0].set_ylabel('Match Score')
axes[0].set_title('Resume Length vs Match Score')

axes[1].scatter(df_plot['jd_len'], df_plot['match_score'], alpha=0.5, color='coral')
axes[1].set_xlabel('JD Word Count')
axes[1].set_ylabel('Match Score')
axes[1].set_title('JD Length vs Match Score')

plt.tight_layout()
plt.show()

# Actual correlation values
print("Resume length correlation:", df_plot['resume_len'].corr(df_plot['match_score']).round(3))
print("JD length correlation:    ", df_plot['jd_len'].corr(df_plot['match_score']).round(3))
# Out:
# Resume length correlation: 0.505
# JD length correlation:     0.497

# %%
plt.figure(figsize=(7, 5))
corr = df_plot[['resume_len', 'jd_len', 'match_score']].corr()
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.19.3 in C:\ProgramData\anaconda3\Lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in C:\ProgramData\anaconda3\Lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in C:\ProgramData\anaconda3\Lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\ProgramData\anaconda3\Lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.6-cp312-cp312-win_amd64.whl (307 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\ProgramData\anaconda3\python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
labels  = ['low', 'medium', 'high']
colors  = ['Reds', 'Oranges', 'Greens']

for ax, label, cmap in zip(axes, labels, colors):
    text = ' '.join(df_plot[df_plot['match_label'] == label]['resume_text'].dropna())
    wc = WordCloud(width=500, height=300, background_color='white',
                   colormap=cmap, max_words=80).generate(text)
    ax.imshow(wc, interpolation='bilinear')
    ax.axis('off')
    ax.set_title(f'{label.upper()} match resumes', fontsize=14, fontweight='bold')

plt.suptitle('Most Common Words by Match Label', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Always record the starting point so that you  can see what changed
print("BEFORE CLEANING")
print("=" * 40)
print(f"Total rows:       {len(df)}")
print(f"Null resume_text: {df['resume_text'].isnull().sum()}")
print(f"Null job_desc:    {df['job_description'].isnull().sum()}")
print(f"Duplicates:       {df.duplicated().sum()}")
print(f"Label variants:   {df['match_label'].nunique()}")
print(f"Invalid scores:   {((df['match_score'] < 0) | (df['match_score'] > 1)).sum()}")
# Out:
# BEFORE CLEANING
# ========================================
# Total rows:       320
# Null resume_text: 0
# Null job_desc:    0
# Duplicates:       4
# Label variants:   3
# Invalid scores:   0

# %%
df_clean = df.copy()

# %%
# Problem: 'high', 'High', 'HIGH' are treated as 3 different categories
print("Before:", df_clean['match_label'].value_counts().to_dict())

df_clean['match_label'] = df_clean['match_label'].str.lower().str.strip()

print("After: ", df_clean['match_label'].value_counts().to_dict())
print(f"\nUnique labels now: {df_clean['match_label'].nunique()} (expected 3)")
# Out:
# Before: {'high': 160, 'medium': 80, 'low': 80}
# After:  {'high': 160, 'medium': 80, 'low': 80}
#
# Unique labels now: 3 (expected 3)

# %%
print(f"Before dropping nulls: {len(df_clean)} rows")

df_clean = df_clean.dropna(subset=['resume_text', 'job_description'])

print(f"After dropping nulls:  {len(df_clean)} rows")
print(f"Removed: {len(df) - len(df_clean)} rows")
# Out:
# Before dropping nulls: 320 rows
# After dropping nulls:  320 rows
# Removed: 0 rows

# %%
print(f"Before removing duplicates: {len(df_clean)} rows")
print(f"Duplicate pairs found: {df_clean.duplicated(subset=['resume_text','job_description']).sum()}")

df_clean = df_clean.drop_duplicates(subset=['resume_text', 'job_description'], keep='first')

print(f"After removing duplicates:  {len(df_clean)} rows")
# Out:
# Before removing duplicates: 320 rows
# Duplicate pairs found: 25
# After removing duplicates:  295 rows

# %%
# Scores must be in [0.0, 1.0], anything else is a data error
invalid_mask = (df_clean['match_score'] < 0.0) | (df_clean['match_score'] > 1.0)
print(f"Invalid scores found: {invalid_mask.sum()}")
print(df_clean[invalid_mask][['match_label','match_score']])

df_clean = df_clean[~invalid_mask]
print(f"\nRows after removing invalid scores: {len(df_clean)}")
# Out:
# Invalid scores found: 0
# Empty DataFrame
# Columns: [match_label, match_score]
# Index: []
#
# Rows after removing invalid scores: 295

# %%
#are the scores consistent with what the label claims?
# Expected: low=0.05-0.35, medium=0.40-0.70, high=0.75-0.95

print("Score range per label:")
print(df_clean.groupby('match_label')['match_score'].agg(['min','max','mean']).round(2))

# Flag any rows where label and score contradict each other
def label_score_mismatch(row):
    score = row['match_score']
    label = row['match_label']
    if label == 'high'   and score < 0.70: return True
    if label == 'medium' and (score < 0.35 or score > 0.75): return True
    if label == 'low'    and score > 0.40: return True
    return False

mismatches = df_clean.apply(label_score_mismatch, axis=1)
print(f"\nLabel-score mismatches: {mismatches.sum()}")
df_clean[mismatches][['match_label','match_score']]
# Out:
# Score range per label:
#               min   max  mean
# match_label
# high         0.83  0.95  0.89
# low          0.10  0.34  0.21
# medium       0.50  0.72  0.61
#
# Label-score mismatches: 0
# Empty DataFrame
# Columns: [match_label, match_score]
# Index: []

# %%
# A 15-character resume or JD is useless for training
df_clean['resume_len'] = df_clean['resume_text'].str.split().str.len()
df_clean['jd_len']     = df_clean['job_description'].str.split().str.len()

print("Short texts found:")
print(f"  resume_text < 20 words: {(df_clean['resume_len'] < 20).sum()}")
print(f"  job_description < 10 words: {(df_clean['jd_len'] < 10).sum()}")

df_clean = df_clean[(df_clean['resume_len'] >= 20) & (df_clean['jd_len'] >= 10)]
print(f"\nRows after removing short texts: {len(df_clean)}")
# Out:
# Short texts found:
#   resume_text < 20 words: 0
#   job_description < 10 words: 0
#
# Rows after removing short texts: 295

# %%
df_clean = df_clean.reset_index(drop=True)

print("=" * 45)
print("CLEANING SUMMARY")
print("=" * 45)
print(f"  Original rows:        {len(df)}")
print(f"  Final rows:           {len(df_clean)}")
print(f"  Rows removed:         {len(df) - len(df_clean)}")
print()
print(f"  Nulls remaining:      {df_clean.isnull().sum().sum()}")
print(f"  Duplicates remaining: {df_clean.duplicated().sum()}")
print(f"  Label variants:       {df_clean['match_label'].nunique()}")
print(f"  Score range:          {df_clean['match_score'].min()} – {df_clean['match_score'].max()}")
print()
print("Label distribution after cleaning:")
print(df_clean['match_label'].value_counts())
print("=" * 45)
# Out:
# =============================================
# CLEANING SUMMARY
# =============================================
#   Original rows:        320
#   Final rows:           295
#   Rows removed:         25
#
#   Nulls remaining:      0
#   Duplicates remaining: 0
#   Label variants:       3
#   Score range:          0.1 – 0.95
#
# Label distribution after cleaning:
# match_label
# high      148
# low        76
# medium     71
# Name: count, dtype: int64
# =============================================

# %%
# Drop the helper columns we added during EDA
df_clean.to_csv('dataset/cleaned_resumeJD_pairs.csv', index=False)
print(f"Saved: dataset/cleaned_resumeJD_pairs.csv ({len(df_clean)} rows)")
# Out:
# Saved: dataset/cleaned_resumeJD_pairs.csv (295 rows)
